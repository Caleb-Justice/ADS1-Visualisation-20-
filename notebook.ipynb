# %% [markdown]
# ## APPLIED DATA SCIENCE 1 ASSIGNMENT
# ### ON
# ### VISUALISATION (20%)
# ### BY
# ### Caleb Vite Justice

# %% [markdown]
# #### Context

# %% [markdown]
# IMDB (Internet Movie Database) is one of the largest online databases for movies and television shows, providing comprehensive information about movies, including ratings and reviews from its vast user base. The IMDB ratings are widely used as a benchmark for the popularity and success of movies.
#
# This dataset contains the top 250 rated movies on IMDB as of 2021, providing a snapshot of the most popular and highly rated movies of recent times. By analyzing this dataset, one can gain insights into the movie industry, such as trends in movie ratings and popular genres.
#
# The data was scraped from the IMDB website for educational purposes and to provide a publicly available dataset for others to use and build upon.
# I wanted to explore and understand the factors that contribute to a movie's popularity and success. IMDB is one of the largest and most trusted movie rating websites, so I decided to scrape its top 250 movies to gain insights into the movie-making industry.

# %% [markdown]
# #### Libraries and Data Importation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_imdb = pd.read_excel("IMDB Top 250 Movies.xlsx", index_col = "rank")

# %%
df_imdb
# Out:
#                           name  year  rating                       genre  \
# rank
# 1     The Shawshank Redemption  1994     9.3                       Drama
# 2                The Godfather  1972     9.2                 Crime,Drama
# 3              The Dark Knight  2008     9.0          Action,Crime,Drama
# 4        The Godfather Part II  1974     9.0                 Crime,Drama
# 5                 12 Angry Men  1957     9.0                 Crime,Drama
# ...                        ...   ...     ...                         ...
# 246                   The Help  2011     8.1                       Drama
# 247                Dersu Uzala  1975     8.2   Adventure,Biography,Drama
# 248                    Aladdin  1992     8.0  Animation,Adventure,Comedy
# 249                     Gandhi  1982     8.0     Biography,Drama,History
# 250         Dances with Wolves  1990     8.0     Adventure,Drama,Western
#
#      certificate  run_time(ms)  \
# rank
# 1              R         142.0
# 2              R         175.0
# 3          PG-13         152.0
# 4              R         142.0
# 5       Approved         156.0
# ...          ...           ...
# 246        PG-13         146.0
# 247            G         142.0
# 248            G          90.0
# 249           PG         191.0
# 250        PG-13         181.0
#
#                                                 tagline     budget  \
# rank
# 1     Fear can hold you prisoner. Hope can set you f...   25000000
# 2                            An offer you can't refuse.    6000000
# 3                                       Why So Serious?  185000000
# 4          All the power on earth can't change destiny.   13000000
# 5     Life Is In Their Hands -- Death Is On Their Mi...     350000
# ...                                                 ...        ...
# 246                       Change begins with a whisper.   25000000
# 247   There is man and beast at nature's mercy. Ther...    4000000
# 248                      Wish granted! (DVD re-release)        NaN
# 249              His Triumph Changed The World Forever.   22000000
# 250   Inside everyone is a frontier waiting to be di...   22000000
#
#         box_office                                              casts  \
# rank
# 1     2.888450e+07  Tim Robbins,Morgan Freeman,Bob Gunton,William ...
# 2     2.503418e+08  Marlon Brando,Al Pacino,James Caan,Diane Keato...
# 3     1.006234e+09  Christian Bale,Heath Ledger,Aaron Eckhart,Mich...
# 4     4.796192e+07  Al Pacino,Robert De Niro,Robert Duvall,Diane K...
# 5     9.550000e+02  Henry Fonda,Lee J. Cobb,Martin Balsam,John Fie...
# ...            ...                                                ...
# 246   2.166391e+08  Viola Davis,Emma Stone,Octavia Spencer,Bryce D...
# 247   1.448000e+04  Maksim Munzuk,Yuriy Solomin,Mikhail Bychkov,Vl...
# 248            NaN  Scott Weinger,Robin Williams,Linda Larkin,Jona...
# 249   5.276789e+07  Ben Kingsley,John Gielgud,Rohini Hattangadi,Ro...
# 250   4.242088e+08  Kevin Costner,Mary McDonnell,Graham Greene,Rod...
#
#                      directors  \
# rank
# 1               Frank Darabont
# 2         Francis Ford Coppola
# 3            Christopher Nolan
# 4         Francis Ford Coppola
# 5                 Sidney Lumet
# ...                        ...
# 246                Tate Taylor
# 247             Akira Kurosawa
# 248   Ron Clements,John Musker
# 249       Richard Attenborough
# 250              Kevin Costner
#
#                                               writers
# rank
# 1                         Stephen King,Frank Darabont
# 2                     Mario Puzo,Francis Ford Coppola
# 3     Jonathan Nolan,Christopher Nolan,David S. Goyer
# 4                     Francis Ford Coppola,Mario Puzo
# 5                                       Reginald Rose
# ...                                               ...
# 246                      Tate Taylor,Kathryn Stockett
# 247     Akira Kurosawa,Yuriy Nagibin,Vladimir Arsenev
# 248              Ron Clements,John Musker,Ted Elliott
# 249                                       John Briley
# 250                                     Michael Blake
#
# [250 rows x 12 columns]
